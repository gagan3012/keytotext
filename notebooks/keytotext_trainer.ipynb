# %% [markdown]
# <a href="https://colab.research.google.com/github/gagan3012/keytotext/blob/master/notebooks/keytotext_trainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keytotext --upgrade
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 1.2MB 9.7MB/s
# ...
#      |████████████████████████████████| 1.8MB 26.1MB/s
# ...
#      |████████████████████████████████| 808kB 48.5MB/s
# ...
#      |████████████████████████████████| 2.3MB 51.2MB/s
# ...
#      |████████████████████████████████| 133kB 49.6MB/s
# ...
#      |████████████████████████████████| 174kB 50.1MB/s
# ...
#      |████████████████████████████████| 102kB 13.4MB/s
# ...
#      |████████████████████████████████| 10.6MB 19.9MB/s
# ...
#      |████████████████████████████████| 276kB 52.4MB/s
# ...
#      |████████████████████████████████| 112kB 56.0MB/s
# ...
#      |████████████████████████████████| 829kB 47.8MB/s
# ...
#      |████████████████████████████████| 3.3MB 46.6MB/s
# ...
#      |████████████████████████████████| 901kB 44.5MB/s
# ...
#      |████████████████████████████████| 71kB 10.2MB/s
# ...
#      |████████████████████████████████| 1.3MB 40.6MB/s
# ...
#      |████████████████████████████████| 143kB 57.8MB/s
# ...
#      |████████████████████████████████| 296kB 51.0MB/s
# ...

# %%
from datasets import load_dataset

dataset = load_dataset('common_gen',split='train')
# Out:
# ...
# Using custom data configuration default
# ...
# Dataset common_gen downloaded and prepared to /root/.cache/huggingface/datasets/common_gen/default/2020.5.30/1a9e8bdc026c41ce7a9e96260debf7d2809cb7fd63fa02b017e4fac1b00c6b23. Subsequent calls will reuse this data.

# %%
import pandas as pd

df = pd.DataFrame()
df['keywords']=dataset['concepts']
df['text'] = dataset['target']
df.head()
# Out:
#                  keywords                                          text
# 0  [ski, mountain, skier]                  Skier skis down the mountain
# 1  [ski, mountain, skier]            A skier is skiing down a mountain.
# 2  [ski, mountain, skier]  Three skiers are skiing on a snowy mountain.
# 3        [wag, tail, dog]                  The dog is wagging his tail.
# 4        [wag, tail, dog]               A dog wags his tail at the boy.

# %%
def clean(keywords):
  source_text = ' '.join(map(str, keywords))
  return source_text

# %%
df['keywords'] = df['keywords'].apply(lambda x: clean(x))
df.head()
# Out:
#              keywords                                          text
# 0  ski mountain skier                  Skier skis down the mountain
# 1  ski mountain skier            A skier is skiing down a mountain.
# 2  ski mountain skier  Three skiers are skiing on a snowy mountain.
# 3        wag tail dog                  The dog is wagging his tail.
# 4        wag tail dog               A dog wags his tail at the boy.

# %%
from keytotext import KeytotextTrainer

model = KeytotextTrainer()
model.from_pretrained(model_name="t5-base")
model.train(data_df=df[:1000],batch_size=4, max_epochs=3, use_gpu=True)
model.save_model()
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-674dcaf5ccf1> in <module>()
#       3 model = KeytotextTrainer()
#       4 model.from_pretrained(model_name="t5-base")
# ----> 5 model.train(data_df=df[:1000],batch_size=4, max_epochs=3, use_gpu=True)
#       6 model.save_model()
#
# /usr/local/lib/python3.7/dist-packages/keytotext/trainer.py in train(self, data_df, source_max_token_len, target_max_token_len, batch_size, max_epochs, use_gpu, outputdir, early_stopping_patience_epochs, test_split)
#     312         )
#     313
# --> 314         trainer.fit(self.T5Model, self.data_module)
#     315
#     316     def load_model(
#
# ...

# %%
model.load_model("/content/Outputs/keytotext-epoch-3", use_gpu=True)

keywords=["ski", "mountain", "sky"]
model.predict(keywords)
# Out:
# 'a mountain of skis on the sky'
